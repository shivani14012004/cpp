# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani14012004/cpp/blob/main/Copy_of_Day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Lists Methods**

# %%
#Syntax:[]

# %%
#Features of the List
#Background data structure-Array
#It supports Indexing and Slicing
#It accepts all types of data
#WE can create homo and hetro list
#It preserves sequence order
#It allows duplicate

#Interview Q1).Explain Features of a list?

# %%
help(list.append)
# Out:
# Help on method_descriptor:
#
# append(self, object, /) unbound builtins.list method
#     Append object to the end of the list.

# %%
#Q2). How to create an empty list?
#eg
a=[]
a
# Out:
# []

# %%
#2
b=list()
b
# Out:
# []

# %%
#Assignment:How to create an empty string

# %%
a='  '
a
# Out:
# '  '

# %%
a
# Out:
# []

# %%
#to add elements in empty list/a normal then use append(object)method

a.append(100)
a
# Out:
# [100, 100, (2, 3, 4), 'c++', 100]

# %%
#Assignment:try to add str,list,tuple,set dict

# %%
#operations in list are inplace/parment.
a
# Out:
# [100, 100]

# %%
data=(2,3,4)
data
# Out:
# (2, 3, 4)

# %%
#add above data in a
a.append(data)#
a
# Out:
# [100, 100, (2, 3, 4)]

# %%
#add c++
a.append('c++')
a
# Out:
# [100, 100, (2, 3, 4), 'c++']

# %%
#append adds a complete object as it is

# %%
#use extend() to add individual elements from an iter

# %%
b
# Out:
# []

# %%
b.extend(data)
b
# Out:
# [2, 3, 4]

# %%
b.extend('c++')
b
# Out:
# [2, 3, 4, 'c', '+', '+']

# %%
#Q3).append vs extend

# %%
#to remove elements from list we have 2 methods
#pop(default removes last element)

b
# Out:
# [2, 3, 4, 'c', '+', '+']

# %%
b.pop()
# Out:
# '+'

# %%
b
# Out:
# [2, 3, 4, 'c', '+']

# %%
a
# Out:
# [100, 100, (2, 3, 4), 'c++', 100]

# %%
a.pop()
# Out:
# 100

# %%
a
# Out:
# [100, 100, (2, 3, 4), 'c++', 100]

# %%
#pop default removes last element

# %%
k=[1,2,3,4,5,6,7]
k
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
#pop(index)-->we can remove element with its index
k.pop(2)
# Out:
# 3

# %%
k
# Out:
# [1, 2, 4, 5, 6, 7]

# %%
help(k.pop)
# Out:
# Help on built-in function pop:
#
# pop(index=-1, /) method of builtins.list instance
#     Remove and return item at index (default last).
#
#     Raises IndexError if list is empty or index is out of range.

# %%
#2 method Remove(value)
k
# Out:
# [1, 2, 4, 5, 6, 7]

# %%
k.remove(6)

# %%
k
# Out:
# [1, 2, 4, 5, 7]

# %%
#Q4).Differnce between remove and pop

# %%
#when there is duplicate
help(k.remove)
# Out:
# Help on built-in function remove:
#
# remove(value, /) method of builtins.list instance
#     Remove first occurrence of value.
#
#     Raises ValueError if the value is not present.

# %%
t =[1,2,3,1,1,4,5,1,1]
t.remove(1)

# %%
t
# Out:
# [2, 3, 1, 1, 4, 5, 1, 1]

# %%
t.remove(1)
t
# Out:
# [2, 3, 1, 4, 5, 1, 1]

# %%
t.remove(1)
t
# Out:
# [2, 3, 4, 5, 1, 1]

# %%
#3 removes all elements
k.clear()
k
# Out:
# []

# %%
t
# Out:
# [2, 3, 4, 5, 1, 1]

# %%
#Shallow copy - list with same element but ids are different

x=t.copy()
x
# Out:
# [2, 3, 4, 5, 1, 1]

# %%
#add -1 in x

x.append(-1)
x
# Out:
# [2, 3, 4, 5, 1, 1, -1]

# %%
t
# Out:
# [2, 3, 4, 5, 1, 1]

# %%
id(t),id(x) #it is a Shallow copy
# Out:
# (135638088404224, 135638085985920)

# %%
#Deep copy
y=x
y
# Out:
# [2, 3, 4, 5, 1, 1, -1]

# %%
x
# Out:
# [2, 3, 4, 5, 1, 1, -1]

# %%
id(y),id(x)#Deep copy
# Out:
# (135638085985920, 135638085985920)

# %%
#in above case we have 1 object with different names x,y hence
#if we change in either x/y changes will get reflected in both the list
x.append('python')
x
# Out:
# [2, 3, 4, 5, 1, 1, -1, 'python']

# %%
y
# Out:
# [2, 3, 4, 5, 1, 1, -1, 'python']

# %%
#assignment:Can we add a tuple to a list using extend?
#Ans:- Yes, we can add tuple to a list using extend because

# %%
r1=[]
r1
# Out:
# []

# %%
r2=[]
r2
# Out:
# []

# %%
id(r1),id(r2)
# Out:
# (135638086187264, 135638085979392)

# %%
r4=[]
r4
# Out:
# []

# %%
r4=r2
r4
# Out:
# []

# %%
r2
# Out:
# []

# %%
id(r2),id(r4)
# Out:
# (135638085962560, 135638085962560)

# %%
z=[]
z
# Out:
# []

# %%
z.append(100)
z
# Out:
# [100]

# %%
z.append('shivani')
z
# Out:
# [100, 'shivani']

# %%
z.append({12,23})
z
# Out:
# [1, 2, [1, 2], (10, 20), {12, 23}]

# %%
z.append([1,2])
z
# Out:
# [1, 2, [1, 2]]

# %%
z.append((10,20))
z
# Out:
# [1, 2, [1, 2], (10, 20)]

# %%
s=[]
s
# Out:
# []

# %%
s.extend('python')
s
# Out:
# ['p', 'y', 't', 'h', 'o', 'n']

# %%
s.extend([11,22])
s
# Out:
# ['p', 'y', 't', 'h', 'o', 'n', 11, 22]

# %%
s.extend((20,30))
s
# Out:
# ['p', 'y', 't', 'h', 'o', 'n', 11, 22, 20, 30]

# %%
s.extend({40,50})
s
# Out:
# ['p', 'y', 't', 'h', 'o', 'n', 11, 22, 20, 30, 40, 50]

# %%
s.extend({2:200,3:300})
s
# Out:
# ['p', 'y', 't', 'h', 'o', 'n', 11, 22, 20, 30, 40, 50, 2, 3]

# %%
d=[]
d
# Out:
# []

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_915/749472965.py in <cell line: 0>()
# ----> 1 d.append(100,300,400,500)
#       2 d
#
# TypeError: list.append() takes exactly one argument (4 given)
