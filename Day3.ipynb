# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani14012004/cpp/blob/main/Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Basic of Data Types**

# %%
#Set
#Syntax:{at least one element} on;y carly bracket doesnt makes seense
type({})
# Out:
# dict

# %%
type({12})
# Out:
# set

# %%
a = {1,2,3,4}
a
# Out:
# {1, 2, 3, 4}

# %%
b={'A',3,44,'pYTHON'}
b
# Out:
# {3, 44, 'A', 'pYTHON'}

# %%
#dict:
#Syntax:{key:value}

d1={1:100,2:200,3:300}
d1
# Out:
# {1: 100, 2: 200, 3: 300}

# %%
type(d1)
# Out:
# dict

# %% [markdown]
# String

# %%
#String is  Immutable data type
#we can not change the string ones it is created and we cant modify or update the string.

# %%
#String background data structure is an array.
#arry is a collection of squencetial element.
#s='python'
#p--->0
#y--->1
#t--->2
#so on

# %%
s='python'

#indexing access only single element at a time
s[0]      #indexing will give in square[]
# Out:
# 'p'

# %%
#vIMP indexing is of two types
#+ve indexing ---->Starts with 0 and ends at (n-1) n means total chars/block(left to right)
#-ve indexing --->starts with -1 and ends at -n (right to left)

# %%
s='python'
s[-1]
# Out:
# 'n'

# %%
#Slicing[Start:Stop:Step]
#using this we can access many than one point

# %%
s
# Out:
# 'python'

# %%
s[2:] #[Start:Stop] # stop is exclusive means element at this index position will not be in the output
# Out:
# 'thon'

# %%
s[2:-1]
# Out:
# 'tho'

# %%
s[2:5]
# Out:
# 'tho'

# %%
#Assignment
#Access PY
#Access YTH
#Access HO

# %%
s[3:-1]
# Out:
# 'ho'

# %%
s[1:-2]
# Out:
# 'yth'

# %%
s[1:2]
# Out:
# 'y'

# %%
s[0:2],s[1:2]
# Out:
# ('py', 'y')

# %%
addrs ='Near DMart pin-411012'
addrs[-6:]
# Out:
# '411012'

# %%
#[Start:Stop:Step]

s[2::1]  #:1 is a steping
# Out:
# 'thon'

# %%
#[Start:Stop:Step]
n='Shivani Patil'
#reverse the steping
n[::-1]
# Out:
# 'litaP inavihS'

# %%
n='Shivani Patil'
#reverse the steping
n[1::-1]
# Out:
# 'hS'

# %%
n='Shivani Patil'
#reverse the steping
n[2::-1]
# Out:
# 'ihS'

# %%
#Assignment
#p='I love my India'
#Access my,India,I love,ove,love ,my,india

# %%
p='I love my India'
p[2:6],p[7:-6],p[:6],p[3:-9],p[10:]
# Out:
# ('love', 'my', 'I love', 'ove', 'India')

# %%
s[::2] #interview Q1 ::2 means which steps 1 to 3 index
# Out:
# 'pto'

# %% [markdown]
# #**String Methods**

# %%
s
# Out:
# 'python'

# %%
#convert str in upper case
s.upper()
# Out:
# 'PYTHON'

# %%
#Capitilize Method
s.capitalize()
# Out:
# 'Python'

# %%
'shivani patil'.title()
# Out:
# 'Shivani Patil'

# %%
#To Remove spaces present in prefix and suffix use strip() method

'  python   '.strip()#default strip removes space
# Out:
# 'python'

# %%
'*******JAVA******'.strip('*')
# Out:
# 'JAVA'

# %%
'**______PYTHON____**'.strip('_*')
# Out:
# 'PYTHON'

# %%
#Assignment
#REmove spaces present in between
' J A V A '

' J A 999 V 777 A '
# Out:
# 'J A V A'

# %%
#' J A 999 V 777 A '
s = 'J A 999 V 777 A'
print(s.strip('999'))
# Out:
# J A 999 V 777 A

# %%
#Assignment: check casefold()
#What is difference between Casefold and lower()

# %%
#When we want to convert lower to upper and vice verse use swapcase()

h='gooD ShivaNI'
h.swapcase()
# Out:
# 'GOOd sHIVAni'

# %%
a='gooD ShivaNI'
a.swapcase()
# Out:
# 'GOOd sHIVAni'

# %%
h.

# %%
code ='cbr1-adgjhfjfnkjhskgfhfsjkjs'
code.startswith('cbr')#it will return boolean output
# Out:
# True

# %%
code.endswith('abc')
# Out:
# False

# %%
code.endswith('kjs')
# Out:
# True

# %%
#join is used to prepare a string using a collection

adhar=['1234','456','678']
#prepare a str of adhar
'-'.join(adhar)
# Out:
# '1234-456-678'

# %%
adhar='Python'
#prepare a str of adhar
'--'.join(adhar)
# Out:
# 'P--y--t--h--o--n'

# %%
name='Shivani'
'-'.join(name)
# Out:
# 'S-h-i-v-a-n-i'

# %%
name='shivanipatil'
'  '.join(name)
# Out:
# 's  h  i  v  a  n  i  p  a  t  i  l'
